# %%
#!/usr/bin/env python
import pygame
from __future__ import print_function
import os
os.environ["CUDA_VISIVBLE_DEVICES"] = '0'
import tensorflow as tf
import cv2
import sys
sys.path.append("game/")
import wrapped_flappy_bird as game
import random
import numpy as np
from collections import deque
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
print('tensorflow version: ',tf.__version__)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14193368364188291436
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11453451469
# locality {
#   bus_id: 1
# }
# incarnation: 4578169034322647405
# physical_device_desc: "device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 11970700903
# locality {
#   bus_id: 1
# }
# incarnation: 16601661021934340058
# physical_device_desc: "device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1"
# , name: "/device:GPU:2"
# device_type: "GPU"
# memory_limit: 11970700903
# locality {
#   bus_id: 1
# }
# incarnation: 15922401563597657872
# physical_device_desc: "device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1"
# ]
# tensorflow version:  1.4.0

# %%
import pygame
from __future__ import print_function
import numpy as np
from collections import deque
import cv2

# %%
GAME = 'bird' # the name of the game being played for log files
ACTIONS = 2 # number of valid actions
GAMMA = 0.99 # decay rate of past observations
OBSERVE = 10000. # timesteps to observe before training
EXPLORE = 3000000. # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.0001 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 32 # size of minibatch
FRAME_PER_ACTION = 1

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev = 0.01)
    return tf.Variable(initial)

# %%
def bias_variable(shape):
    initial = tf.constant(0.01, shape = shape)
    return tf.Variable(initial)

# %%
def conv2d(x, W, stride):
    return tf.nn.conv2d(x, W, strides = [1, stride, stride, 1], padding = "SAME")

# %%
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = "SAME")

# %%
def createNetwork():
    # network weights
    W_conv1 = weight_variable([8, 8, 4, 32])
    b_conv1 = bias_variable([32])

    W_conv2 = weight_variable([4, 4, 32, 64])
    b_conv2 = bias_variable([64])

    W_conv3 = weight_variable([3, 3, 64, 64])
    b_conv3 = bias_variable([64])

    W_fc1 = weight_variable([1600, 512])
    b_fc1 = bias_variable([512])

    W_fc2 = weight_variable([512, ACTIONS])
    b_fc2 = bias_variable([ACTIONS])

    # input layer
    s = tf.placeholder("float", [None, 80, 80, 4])

    # hidden layers
    h_conv1 = tf.nn.relu(conv2d(s, W_conv1, 4) + b_conv1)
    h_pool1 = max_pool_2x2(h_conv1)

    h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2, 2) + b_conv2)
    #h_pool2 = max_pool_2x2(h_conv2)

    h_conv3 = tf.nn.relu(conv2d(h_conv2, W_conv3, 1) + b_conv3)
    #h_pool3 = max_pool_2x2(h_conv3)

    #h_pool3_flat = tf.reshape(h_pool3, [-1, 256])
    h_conv3_flat = tf.reshape(h_conv3, [-1, 1600])

    h_fc1 = tf.nn.relu(tf.matmul(h_conv3_flat, W_fc1) + b_fc1)

    # readout layer
    readout = tf.matmul(h_fc1, W_fc2) + b_fc2

    return s, readout, h_fc1

# %%
def trainNetwork(s, readout, h_fc1, sess):
    # define the cost function
    a = tf.placeholder("float", [None, ACTIONS])
    y = tf.placeholder("float", [None])
    readout_action = tf.reduce_sum(tf.multiply(readout, a), reduction_indices=1)
    cost = tf.reduce_mean(tf.square(y - readout_action))
    train_step = tf.train.AdamOptimizer(1e-6).minimize(cost)

    # open up a game state to communicate with emulator
    game_state = game.GameState()

    # store the previous observations in replay memory
    D = deque()

    # printing
    a_file = open("logs_" + GAME + "/readout.txt", 'w')
    h_file = open("logs_" + GAME + "/hidden.txt", 'w')

    # get the first state by doing nothing and preprocess the image to 80x80x4
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] = 1
    x_t, r_0, terminal = game_state.frame_step(do_nothing)
    x_t = cv2.cvtColor(cv2.resize(x_t, (80, 80)), cv2.COLOR_BGR2GRAY)
    ret, x_t = cv2.threshold(x_t,1,255,cv2.THRESH_BINARY)
    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2)

    # saving and loading networks
    saver = tf.train.Saver()
    sess.run(tf.initialize_all_variables())
    checkpoint = tf.train.get_checkpoint_state("saved_networks")
    if checkpoint and checkpoint.model_checkpoint_path:
        saver.restore(sess, checkpoint.model_checkpoint_path)
        print("Successfully loaded:", checkpoint.model_checkpoint_path)
    else:
        print("Could not find old network weights")

    # start training
    epsilon = INITIAL_EPSILON
    t = 0
    
    while "flappy bird" != "angry bird":
        # choose an action epsilon greedily
        readout_t = readout.eval(feed_dict={s : [s_t]})[0]
        a_t = np.zeros([ACTIONS])
        action_index = 0
        if t % FRAME_PER_ACTION == 0:
            if random.random() <= epsilon:
                print("----------Random Action----------")
                
                if random.random() < 0.1 :
                    a_t[1] = 1
                    action_index = 1
                else:
                    a_t[0] = 1
                    action_index = 0
            else:
                action_index = np.argmax(readout_t)
                a_t[action_index] = 1
        else:
            a_t[0] = 1 # do nothing

        # scale down epsilon
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        # run the selected action and observe next state and reward
        x_t1_colored, r_t, terminal = game_state.frame_step(a_t)
        x_t1 = cv2.cvtColor(cv2.resize(x_t1_colored, (80, 80)), cv2.COLOR_BGR2GRAY)
        ret, x_t1 = cv2.threshold(x_t1, 1, 255, cv2.THRESH_BINARY)
        x_t1 = np.reshape(x_t1, (80, 80, 1))
        #s_t1 = np.append(x_t1, s_t[:,:,1:], axis = 2)
        s_t1 = np.append(x_t1, s_t[:, :, :3], axis=2)

        # store the transition in D
        D.append((s_t, a_t, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        # only train if done observing
        if t > OBSERVE:
            # sample a minibatch to train on
            minibatch = random.sample(D, BATCH)

            # get the batch variables
            s_j_batch = [d[0] for d in minibatch]
            a_batch = [d[1] for d in minibatch]
            r_batch = [d[2] for d in minibatch]
            s_j1_batch = [d[3] for d in minibatch]

            y_batch = []
            readout_j1_batch = readout.eval(feed_dict = {s : s_j1_batch})
            for i in range(0, len(minibatch)):
                terminal = minibatch[i][4]
                # if terminal, only equals reward
                if terminal:
                    y_batch.append(r_batch[i])
                else:
                    y_batch.append(r_batch[i] + GAMMA * np.max(readout_j1_batch[i]))

            # perform gradient step
            train_step.run(feed_dict = {
                y : y_batch,
                a : a_batch,
                s : s_j_batch}
            )

        # update the old values
        s_t = s_t1
        t += 1

        # save progress every 10000 iterations
        if t % 10000 == 0:
            saver.save(sess, 'saved_networks/' + GAME + '-dqn', global_step = t)

        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, \
            "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, \
            "/ Q_MAX %e" % np.max(readout_t))
        # write info to files
        '''
        if t % 10000 <= 100:
            a_file.write(",".join([str(x) for x in readout_t]) + '\n')
            h_file.write(",".join([str(x) for x in h_fc1.eval(feed_dict={s:[s_t]})[0]]) + '\n')
            cv2.imwrite("logs_tetris/frame" + str(t) + ".png", x_t1)
        '''

# %%
def playGame():
    sess = tf.InteractiveSession()
    s, readout, h_fc1 = createNetwork()
    trainNetwork(s, readout, h_fc1, sess)

def main():
    playGame()

if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From /home/user/anaconda2/lib/python2.7/site-packages/tensorflow/python/util/tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# INFO:tensorflow:Restoring parameters from saved_networks/bird-dqn-590000
# Successfully loaded: saved_networks/bird-dqn-590000
# ----------Random Action----------
# TIMESTEP 1 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193735e+01
# TIMESTEP 2 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193025e+01
# TIMESTEP 3 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.186570e+01
# ----------Random Action----------
# TIMESTEP 4 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.185735e+01
# TIMESTEP 5 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191248e+01
# ----------Random Action----------
# TIMESTEP 6 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193458e+01
# TIMESTEP 7 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191990e+01
# TIMESTEP 8 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196165e+01
# ----------Random Action----------
# TIMESTEP 9 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194799e+01
# ----------Random Action----------
# TIMESTEP 10 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.202140e+01
# TIMESTEP 11 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.203263e+01
# TIMESTEP 12 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194205e+01
# ----------Random Action----------
# TIMESTEP 13 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189662e+01
# TIMESTEP 14 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.186069e+01
# ----------Random Action----------
# TIMESTEP 15 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.180956e+01
# ----------Random Action----------
# TIMESTEP 16 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196932e+01
# ----------Random Action----------
# TIMESTEP 17 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.200253e+01
# ----------Random Action----------
# TIMESTEP 18 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.211249e+01
# ----------Random Action----------
# TIMESTEP 19 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.214236e+01
# ----------Random Action----------
# TIMESTEP 20 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.220920e+01
# ----------Random Action----------
# TIMESTEP 21 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222360e+01
# TIMESTEP 22 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.224148e+01
# ----------Random Action----------
# TIMESTEP 23 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.221578e+01
# TIMESTEP 24 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.226179e+01
# ----------Random Action----------
# TIMESTEP 25 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.228456e+01
# TIMESTEP 26 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.237024e+01
# TIMESTEP 27 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.241950e+01
# TIMESTEP 28 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.245921e+01
# TIMESTEP 29 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.248245e+01
# ----------Random Action----------
# TIMESTEP 30 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.244401e+01
# TIMESTEP 31 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.244728e+01
# TIMESTEP 32 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.242313e+01
# ----------Random Action----------
# TIMESTEP 33 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.246073e+01
# TIMESTEP 34 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.236895e+01
# TIMESTEP 35 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.228443e+01
# TIMESTEP 36 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.242273e+01
# TIMESTEP 37 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.235194e+01
# ----------Random Action----------
# TIMESTEP 38 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.230978e+01
# ----------Random Action----------
# TIMESTEP 39 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.236250e+01
# TIMESTEP 40 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.229943e+01
# ----------Random Action----------
# TIMESTEP 41 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.237995e+01
# ----------Random Action----------
# TIMESTEP 42 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.246957e+01
# TIMESTEP 43 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.251525e+01
# TIMESTEP 44 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.245317e+01
# TIMESTEP 45 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.246423e+01
# TIMESTEP 46 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.252960e+01
# ----------Random Action----------
# TIMESTEP 47 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.246532e+01
# TIMESTEP 48 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.249940e+01
# TIMESTEP 49 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.260658e+01
# ----------Random Action----------
# TIMESTEP 50 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.275443e+01
# ----------Random Action----------
# TIMESTEP 51 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX -3.236480e+00
# ----------Random Action----------
# TIMESTEP 52 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.175378e+01
# ----------Random Action----------
# TIMESTEP 53 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187647e+01
# ----------Random Action----------
# TIMESTEP 54 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.177316e+01
# TIMESTEP 55 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184419e+01
# ----------Random Action----------
# TIMESTEP 56 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.188348e+01
# TIMESTEP 57 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192050e+01
# TIMESTEP 58 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196563e+01
# TIMESTEP 59 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191914e+01
# ----------Random Action----------
# TIMESTEP 60 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195198e+01
# TIMESTEP 61 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197529e+01
# TIMESTEP 62 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197434e+01
# ----------Random Action----------
# TIMESTEP 63 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.198230e+01
# TIMESTEP 64 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192020e+01
# TIMESTEP 65 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.191930e+01
# TIMESTEP 66 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.195604e+01
# TIMESTEP 67 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.207734e+01
# ----------Random Action----------
# TIMESTEP 68 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.206698e+01
# ----------Random Action----------
# TIMESTEP 69 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216706e+01
# ----------Random Action----------
# TIMESTEP 70 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215989e+01
# TIMESTEP 71 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219607e+01
# ----------Random Action----------
# TIMESTEP 72 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.220642e+01
# TIMESTEP 73 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.225826e+01
# ----------Random Action----------
# TIMESTEP 74 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.225749e+01
# ----------Random Action----------
# TIMESTEP 75 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.219565e+01
# TIMESTEP 76 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.220990e+01
# TIMESTEP 77 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219858e+01
# ----------Random Action----------
# TIMESTEP 78 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.220927e+01
# ----------Random Action----------
# TIMESTEP 79 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.217019e+01
# ----------Random Action----------
# TIMESTEP 80 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.205774e+01
# ----------Random Action----------
# TIMESTEP 81 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.212719e+01
# TIMESTEP 82 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.207589e+01
# TIMESTEP 83 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.213430e+01
# TIMESTEP 84 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.201469e+01
# ----------Random Action----------
# TIMESTEP 85 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196468e+01
# ----------Random Action----------
# TIMESTEP 86 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187914e+01
# TIMESTEP 87 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194107e+01
# TIMESTEP 88 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.210937e+01
# ----------Random Action----------
# TIMESTEP 89 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.225074e+01
# ----------Random Action----------
# TIMESTEP 90 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.228671e+01
# ----------Random Action----------
# TIMESTEP 91 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.225686e+01
# TIMESTEP 92 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.229892e+01
# ----------Random Action----------
# TIMESTEP 93 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.236684e+01
# TIMESTEP 94 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.243346e+01
# ----------Random Action----------
# TIMESTEP 95 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.255365e+01
# TIMESTEP 96 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.253829e+01
# ----------Random Action----------
# TIMESTEP 97 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.266374e+01
# ----------Random Action----------
# TIMESTEP 98 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.268287e+01
# TIMESTEP 99 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.132093e+01
# ----------Random Action----------
# TIMESTEP 100 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -6.508687e+00
# ----------Random Action----------
# TIMESTEP 101 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -8.514333e+00
# ----------Random Action----------
# TIMESTEP 102 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX -8.169111e+00
# TIMESTEP 103 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.174088e+01
# TIMESTEP 104 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.188571e+01
# TIMESTEP 105 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.173566e+01
# TIMESTEP 106 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.188392e+01
# ----------Random Action----------
# TIMESTEP 107 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.188692e+01
# TIMESTEP 108 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193078e+01
# TIMESTEP 109 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193353e+01
# ----------Random Action----------
# TIMESTEP 110 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193102e+01
# TIMESTEP 111 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196905e+01
# TIMESTEP 112 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195080e+01
# ----------Random Action----------
# TIMESTEP 113 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.203808e+01
# ----------Random Action----------
# TIMESTEP 114 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.204407e+01
# TIMESTEP 115 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196153e+01
# ----------Random Action----------
# TIMESTEP 116 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189705e+01
# ----------Random Action----------
# TIMESTEP 117 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.186187e+01
# ----------Random Action----------
# TIMESTEP 118 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.203425e+01
# ----------Random Action----------
# TIMESTEP 119 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193713e+01
# ----------Random Action----------
# TIMESTEP 120 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.176421e+01
# ----------Random Action----------
# TIMESTEP 121 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX 1.183230e+01
# ----------Random Action----------
# TIMESTEP 122 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.168882e+01
# ----------Random Action----------
# TIMESTEP 123 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.174098e+01
# ----------Random Action----------
# TIMESTEP 124 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.170748e+01
# ----------Random Action----------
# TIMESTEP 125 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.175881e+01
# TIMESTEP 126 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.173638e+01
# TIMESTEP 127 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.177972e+01
# ----------Random Action----------
# TIMESTEP 128 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184565e+01
# TIMESTEP 129 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187782e+01
# ----------Random Action----------
# TIMESTEP 130 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196724e+01
# TIMESTEP 131 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.206626e+01
# TIMESTEP 132 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.211276e+01
# ----------Random Action----------
# TIMESTEP 133 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.206294e+01
# TIMESTEP 134 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.201722e+01
# TIMESTEP 135 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.205570e+01
# ----------Random Action----------
# TIMESTEP 136 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.204374e+01
# ----------Random Action----------
# TIMESTEP 137 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195413e+01
# TIMESTEP 138 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.198138e+01
# ----------Random Action----------
# TIMESTEP 139 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.204507e+01
# TIMESTEP 140 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192997e+01
# ----------Random Action----------
# TIMESTEP 141 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209029e+01
# ----------Random Action----------
# TIMESTEP 142 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215807e+01
# TIMESTEP 143 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.199759e+01
# ----------Random Action----------
# TIMESTEP 144 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.199013e+01
# ----------Random Action----------
# TIMESTEP 145 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.182411e+01
# ----------Random Action----------
# TIMESTEP 146 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.187554e+01
# ----------Random Action----------
# TIMESTEP 147 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.177945e+01
# TIMESTEP 148 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.178736e+01
# ----------Random Action----------
# TIMESTEP 149 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.166768e+01
# ----------Random Action----------
# TIMESTEP 150 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.171658e+01
# ----------Random Action----------
# TIMESTEP 151 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.174993e+01
# ----------Random Action----------
# TIMESTEP 152 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.167909e+01
# TIMESTEP 153 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.167241e+01
# TIMESTEP 154 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.167946e+01
# TIMESTEP 155 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.174078e+01
# ----------Random Action----------
# TIMESTEP 156 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.162307e+01
# ----------Random Action----------
# TIMESTEP 157 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.158683e+01
# TIMESTEP 158 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.162757e+01
# ----------Random Action----------
# TIMESTEP 159 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.158769e+01
# ----------Random Action----------
# TIMESTEP 160 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.155257e+01
# ----------Random Action----------
# TIMESTEP 161 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.147033e+01
# ----------Random Action----------
# TIMESTEP 162 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.137382e+01
# ----------Random Action----------
# TIMESTEP 163 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.141316e+01
# ----------Random Action----------
# TIMESTEP 164 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.150002e+01
# ----------Random Action----------
# TIMESTEP 165 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.142439e+01
# TIMESTEP 166 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.134711e+01
# TIMESTEP 167 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.150133e+01
# ----------Random Action----------
# TIMESTEP 168 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.161702e+01
# ----------Random Action----------
# TIMESTEP 169 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.170520e+01
# TIMESTEP 170 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.173090e+01
# TIMESTEP 171 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.179147e+01
# ----------Random Action----------
# TIMESTEP 172 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.177167e+01
# TIMESTEP 173 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.186667e+01
# TIMESTEP 174 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.188390e+01
# ----------Random Action----------
# TIMESTEP 175 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.201890e+01
# ----------Random Action----------
# TIMESTEP 176 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.165126e+01
# ----------Random Action----------
# TIMESTEP 177 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.135452e+01
# ----------Random Action----------
# TIMESTEP 178 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.208196e+01
# TIMESTEP 179 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215964e+01
# TIMESTEP 180 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.221374e+01
# ----------Random Action----------
# TIMESTEP 181 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.219760e+01
# TIMESTEP 182 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 1 / Q_MAX 1.180130e+01
# ----------Random Action----------
# TIMESTEP 183 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX -3.332430e+00
# ----------Random Action----------
# TIMESTEP 184 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.159979e+01
# TIMESTEP 185 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.160158e+01
# TIMESTEP 186 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189481e+01
# ----------Random Action----------
# TIMESTEP 187 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184419e+01
# ----------Random Action----------
# TIMESTEP 188 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.185516e+01
# ----------Random Action----------
# TIMESTEP 189 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192269e+01
# TIMESTEP 190 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195404e+01
# TIMESTEP 191 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189946e+01
# ----------Random Action----------
# TIMESTEP 192 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194568e+01
# TIMESTEP 193 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197186e+01
# TIMESTEP 194 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197167e+01
# TIMESTEP 195 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.198149e+01
# ----------Random Action----------
# TIMESTEP 196 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191442e+01
# ----------Random Action----------
# TIMESTEP 197 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191340e+01
# ----------Random Action----------
# TIMESTEP 198 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192907e+01
# ----------Random Action----------
# TIMESTEP 199 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.205129e+01
# TIMESTEP 200 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.198270e+01
# TIMESTEP 201 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.190715e+01
# ----------Random Action----------
# TIMESTEP 202 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.200257e+01
# TIMESTEP 203 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.197414e+01
# ----------Random Action----------
# TIMESTEP 204 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216636e+01
# TIMESTEP 205 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.217471e+01
# TIMESTEP 206 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.226371e+01
# TIMESTEP 207 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.230057e+01
# TIMESTEP 208 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.238994e+01
# ----------Random Action----------
# TIMESTEP 209 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.238394e+01
# ----------Random Action----------
# TIMESTEP 210 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.237394e+01
# ----------Random Action----------
# TIMESTEP 211 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234752e+01
# ----------Random Action----------
# TIMESTEP 212 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.232320e+01
# ----------Random Action----------
# TIMESTEP 213 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.236074e+01
# TIMESTEP 214 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234364e+01
# TIMESTEP 215 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234852e+01
# ----------Random Action----------
# TIMESTEP 216 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.233375e+01
# ----------Random Action----------
# TIMESTEP 217 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.237364e+01
# TIMESTEP 218 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.239328e+01
# ----------Random Action----------
# TIMESTEP 219 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.229839e+01
# ----------Random Action----------
# TIMESTEP 220 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.231559e+01
# TIMESTEP 221 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.223432e+01
# ----------Random Action----------
# TIMESTEP 222 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.230039e+01
# TIMESTEP 223 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.233614e+01
# ----------Random Action----------
# TIMESTEP 224 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234587e+01
# TIMESTEP 225 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.235400e+01
# ----------Random Action----------
# TIMESTEP 226 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.236019e+01
# TIMESTEP 227 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.237470e+01
# ----------Random Action----------
# TIMESTEP 228 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.236639e+01
# ----------Random Action----------
# TIMESTEP 229 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.246320e+01
# ----------Random Action----------
# TIMESTEP 230 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.256549e+01
# ----------Random Action----------
# TIMESTEP 231 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.264160e+01
# ----------Random Action----------
# TIMESTEP 232 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.252358e+01
# ----------Random Action----------
# TIMESTEP 233 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 8.847210e-01
# ----------Random Action----------
# TIMESTEP 234 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -9.112942e-01
# TIMESTEP 235 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD -1 / Q_MAX -4.918928e+00
# ----------Random Action----------
# TIMESTEP 236 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189155e+01
# ----------Random Action----------
# TIMESTEP 237 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189688e+01
# TIMESTEP 238 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.173559e+01
# ----------Random Action----------
# TIMESTEP 239 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187050e+01
# ----------Random Action----------
# TIMESTEP 240 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.188617e+01
# TIMESTEP 241 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.190925e+01
# ----------Random Action----------
# TIMESTEP 242 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194665e+01
# ----------Random Action----------
# TIMESTEP 243 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194205e+01
# TIMESTEP 244 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196960e+01
# ----------Random Action----------
# TIMESTEP 245 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195107e+01
# TIMESTEP 246 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.203149e+01
# TIMESTEP 247 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.203465e+01
# ----------Random Action----------
# TIMESTEP 248 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196079e+01
# TIMESTEP 249 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.190096e+01
# TIMESTEP 250 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.193425e+01
# TIMESTEP 251 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.197791e+01
# ----------Random Action----------
# TIMESTEP 252 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.205559e+01
# ----------Random Action----------
# TIMESTEP 253 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.210691e+01
# ----------Random Action----------
# TIMESTEP 254 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215323e+01
# TIMESTEP 255 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216065e+01
# TIMESTEP 256 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.220083e+01
# ----------Random Action----------
# TIMESTEP 257 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219875e+01
# ----------Random Action----------
# TIMESTEP 258 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.224553e+01
# ----------Random Action----------
# TIMESTEP 259 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219220e+01
# TIMESTEP 260 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.221790e+01
# ----------Random Action----------
# TIMESTEP 261 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.226027e+01
# TIMESTEP 262 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.235460e+01
# TIMESTEP 263 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.243320e+01
# TIMESTEP 264 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.245021e+01
# TIMESTEP 265 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.251042e+01
# TIMESTEP 266 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.244270e+01
# TIMESTEP 267 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.242122e+01
# ----------Random Action----------
# TIMESTEP 268 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.245179e+01
# ----------Random Action----------
# TIMESTEP 269 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.245229e+01
# ----------Random Action----------
# TIMESTEP 270 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222975e+01
# ----------Random Action----------
# TIMESTEP 271 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.231386e+01
# TIMESTEP 272 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.179570e+01
# TIMESTEP 273 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.192539e+01
# TIMESTEP 274 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.215247e+01
# TIMESTEP 275 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.238881e+01
# ----------Random Action----------
# TIMESTEP 276 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.238877e+01
# TIMESTEP 277 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.248329e+01
# ----------Random Action----------
# TIMESTEP 278 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.258580e+01
# ----------Random Action----------
# TIMESTEP 279 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.269081e+01
# TIMESTEP 280 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.259452e+01
# TIMESTEP 281 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.261115e+01
# ----------Random Action----------
# TIMESTEP 282 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.266230e+01
# ----------Random Action----------
# TIMESTEP 283 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.264425e+01
# ----------Random Action----------
# TIMESTEP 284 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.256081e+01
# ----------Random Action----------
# TIMESTEP 285 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.265348e+01
# ----------Random Action----------
# TIMESTEP 286 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.272656e+01
# TIMESTEP 287 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.278044e+01
# TIMESTEP 288 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.279229e+01
# ----------Random Action----------
# TIMESTEP 289 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.286569e+01
# TIMESTEP 290 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.290924e+01
# ----------Random Action----------
# TIMESTEP 291 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.291008e+01
# TIMESTEP 292 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.291187e+01
# ----------Random Action----------
# TIMESTEP 293 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.299966e+01
# ----------Random Action----------
# TIMESTEP 294 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.306435e+01
# TIMESTEP 295 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.305326e+01
# TIMESTEP 296 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 1 / Q_MAX 1.308535e+01
# ----------Random Action----------
# TIMESTEP 297 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.233629e+01
# TIMESTEP 298 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215010e+01
# ----------Random Action----------
# TIMESTEP 299 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222589e+01
# TIMESTEP 300 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234804e+01
# ----------Random Action----------
# TIMESTEP 301 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.233872e+01
# ----------Random Action----------
# TIMESTEP 302 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.234224e+01
# TIMESTEP 303 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.238359e+01
# ----------Random Action----------
# TIMESTEP 304 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.238273e+01
# TIMESTEP 305 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.235155e+01
# ----------Random Action----------
# TIMESTEP 306 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.243224e+01
# TIMESTEP 307 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.239006e+01
# ----------Random Action----------
# TIMESTEP 308 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.247209e+01
# ----------Random Action----------
# TIMESTEP 309 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.248986e+01
# TIMESTEP 310 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.263309e+01
# TIMESTEP 311 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.262425e+01
# ----------Random Action----------
# TIMESTEP 312 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.259266e+01
# ----------Random Action----------
# TIMESTEP 313 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.246946e+01
# ----------Random Action----------
# TIMESTEP 314 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.251001e+01
# TIMESTEP 315 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.250510e+01
# ----------Random Action----------
# TIMESTEP 316 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.254401e+01
# TIMESTEP 317 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.259843e+01
# TIMESTEP 318 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.266641e+01
# TIMESTEP 319 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.263886e+01
# ----------Random Action----------
# TIMESTEP 320 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.261755e+01
# ----------Random Action----------
# TIMESTEP 321 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.272027e+01
# ----------Random Action----------
# TIMESTEP 322 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.269266e+01
# ----------Random Action----------
# TIMESTEP 323 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.275849e+01
# TIMESTEP 324 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.279023e+01
# TIMESTEP 325 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.289417e+01
# ----------Random Action----------
# TIMESTEP 326 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.299945e+01
# ----------Random Action----------
# TIMESTEP 327 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.304386e+01
# TIMESTEP 328 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.738659e+00
# ----------Random Action----------
# TIMESTEP 329 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX -2.113740e+00
# TIMESTEP 330 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.167509e+01
# ----------Random Action----------
# TIMESTEP 331 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.161712e+01
# ----------Random Action----------
# TIMESTEP 332 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.170866e+01
# ----------Random Action----------
# TIMESTEP 333 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184419e+01
# ----------Random Action----------
# TIMESTEP 334 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.185516e+01
# TIMESTEP 335 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.192269e+01
# ----------Random Action----------
# TIMESTEP 336 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195404e+01
# TIMESTEP 337 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189946e+01
# ----------Random Action----------
# TIMESTEP 338 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194568e+01
# TIMESTEP 339 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197186e+01
# TIMESTEP 340 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197167e+01
# ----------Random Action----------
# TIMESTEP 341 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.198149e+01
# ----------Random Action----------
# TIMESTEP 342 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.190951e+01
# TIMESTEP 343 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.199674e+01
# TIMESTEP 344 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.207296e+01
# TIMESTEP 345 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.208527e+01
# ----------Random Action----------
# TIMESTEP 346 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209403e+01
# ----------Random Action----------
# TIMESTEP 347 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.214869e+01
# TIMESTEP 348 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.221425e+01
# ----------Random Action----------
# TIMESTEP 349 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.229824e+01
# TIMESTEP 350 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.222148e+01
# TIMESTEP 351 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.216539e+01
# TIMESTEP 352 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.210782e+01
# ----------Random Action----------
# TIMESTEP 353 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.208172e+01
# ----------Random Action----------
# TIMESTEP 354 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.212942e+01
# ----------Random Action----------
# TIMESTEP 355 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215481e+01
# TIMESTEP 356 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215304e+01
# ----------Random Action----------
# TIMESTEP 357 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.208157e+01
# ----------Random Action----------
# TIMESTEP 358 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.199300e+01
# ----------Random Action----------
# TIMESTEP 359 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.204831e+01
# ----------Random Action----------
# TIMESTEP 360 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.199102e+01
# ----------Random Action----------
# TIMESTEP 361 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.199217e+01
# ----------Random Action----------
# TIMESTEP 362 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.199745e+01
# ----------Random Action----------
# TIMESTEP 363 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.201061e+01
# TIMESTEP 364 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.191086e+01
# ----------Random Action----------
# TIMESTEP 365 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.187858e+01
# TIMESTEP 366 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.202311e+01
# ----------Random Action----------
# TIMESTEP 367 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.214841e+01
# ----------Random Action----------
# TIMESTEP 368 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 9.278443e+00
# ----------Random Action----------
# TIMESTEP 369 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 3.771641e+00
# ----------Random Action----------
# TIMESTEP 370 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX -6.992115e-01
# ----------Random Action----------
# TIMESTEP 371 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 2.571171e+00
# TIMESTEP 372 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 2.559862e+00
# ----------Random Action----------
# TIMESTEP 373 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 4.411720e+00
# TIMESTEP 374 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 6.621365e+00
# ----------Random Action----------
# TIMESTEP 375 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 5.113618e+00
# ----------Random Action----------
# TIMESTEP 376 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 6.694589e-01
# TIMESTEP 377 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 2.154761e+00
# TIMESTEP 378 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX -1.620578e+00
# ----------Random Action----------
# TIMESTEP 379 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD -1 / Q_MAX -3.291368e+00
# TIMESTEP 380 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.194279e+01
# TIMESTEP 381 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.188969e+01
# TIMESTEP 382 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.170610e+01
# ----------Random Action----------
# TIMESTEP 383 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.172735e+01
# TIMESTEP 384 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.173520e+01
# ----------Random Action----------
# TIMESTEP 385 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.176536e+01
# TIMESTEP 386 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.182294e+01
# TIMESTEP 387 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.184566e+01
# ----------Random Action----------
# TIMESTEP 388 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.189743e+01
# TIMESTEP 389 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196358e+01
# ----------Random Action----------
# TIMESTEP 390 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.201432e+01
# ----------Random Action----------
# TIMESTEP 391 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197810e+01
# TIMESTEP 392 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.193202e+01
# TIMESTEP 393 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.195371e+01
# TIMESTEP 394 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.197756e+01
# ----------Random Action----------
# TIMESTEP 395 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.210131e+01
# TIMESTEP 396 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.193989e+01
# TIMESTEP 397 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.191990e+01
# TIMESTEP 398 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.196826e+01
# TIMESTEP 399 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.194172e+01
# ----------Random Action----------
# TIMESTEP 400 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.212528e+01
# ----------Random Action----------
# TIMESTEP 401 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.210783e+01
# TIMESTEP 402 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.213789e+01
# TIMESTEP 403 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215049e+01
# TIMESTEP 404 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.218141e+01
# ----------Random Action----------
# TIMESTEP 405 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209971e+01
# ----------Random Action----------
# TIMESTEP 406 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209210e+01
# ----------Random Action----------
# TIMESTEP 407 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.201544e+01
# TIMESTEP 408 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.199313e+01
# TIMESTEP 409 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.198882e+01
# TIMESTEP 410 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.190592e+01
# TIMESTEP 411 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.194286e+01
# TIMESTEP 412 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.197692e+01
# TIMESTEP 413 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.199468e+01
# ----------Random Action----------
# TIMESTEP 414 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.196611e+01
# ----------Random Action----------
# TIMESTEP 415 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.200769e+01
# TIMESTEP 416 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.208481e+01
# TIMESTEP 417 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.209689e+01
# TIMESTEP 418 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.213816e+01
# TIMESTEP 419 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.213214e+01
# ----------Random Action----------
# TIMESTEP 420 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.212578e+01
# ----------Random Action----------
# TIMESTEP 421 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.215902e+01
# TIMESTEP 422 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.219677e+01
# ----------Random Action----------
# TIMESTEP 423 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.217118e+01
# ----------Random Action----------
# TIMESTEP 424 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 9.273954e+00
# ----------Random Action----------
# TIMESTEP 425 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 9.785013e-01
# ----------Random Action----------
# TIMESTEP 426 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 2.124871e+00
# ----------Random Action----------
# TIMESTEP 427 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.999348e+00
# ----------Random Action----------
# TIMESTEP 428 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.916539e+00
# ----------Random Action----------
# TIMESTEP 429 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 7.508603e+00
# TIMESTEP 430 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD -1 / Q_MAX -8.703738e-02
# TIMESTEP 431 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.166438e+01
# TIMESTEP 432 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.171128e+01
# TIMESTEP 433 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.166451e+01
# ----------Random Action----------
# TIMESTEP 434 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.174553e+01
# ----------Random Action----------
# TIMESTEP 435 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.174739e+01
# ----------Random Action----------
# TIMESTEP 436 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.174658e+01
# ----------Random Action----------
# TIMESTEP 437 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.182606e+01
# TIMESTEP 438 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.175091e+01
# ----------Random Action----------
# TIMESTEP 439 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.165367e+01
# TIMESTEP 440 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.170453e+01
# TIMESTEP 441 / STATE observe / EPSILON 0.5 / ACTION 1 / REWARD 0.1 / Q_MAX 1.178336e+01
# ----------Random Action----------
# TIMESTEP 442 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.176211e+01
# ----------Random Action----------
# TIMESTEP 443 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.169727e+01
# TIMESTEP 444 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.175851e+01
# TIMESTEP 445 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.175543e+01
# ----------Random Action----------
# TIMESTEP 446 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.176961e+01
# ----------Random Action----------
# TIMESTEP 447 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.176040e+01
# TIMESTEP 448 / STATE observe / EPSILON 0.5 / ACTION 0 / REWARD 0.1 / Q_MAX 1.170193e+01
# ...
# ----------Random Action----------
# TIMESTEP 16057 / STATE explore / EPSILON 0.498990868533 / ACTION 0 / REWARD 0.1 / Q_MAX 4.930145e+00
# ----------Random Action----------
# TIMESTEP 16058 / STATE explore / EPSILON 0.4989907019 / ACTION 0 / REWARD 0.1 / Q_MAX 5.005034e+00
# ----------Random Action----------
# TIMESTEP 16059 / STATE explore / EPSILON 0.498990535267 / ACTION 0 / REWARD 0.1 / Q_MAX 4.951470e+00
# ----------Random Action----------
# TIMESTEP 16060 / STATE explore / EPSILON 0.498990368633 / ACTION 0 / REWARD 0.1 / Q_MAX 4.918760e+00
# TIMESTEP 16061 / STATE explore / EPSILON 0.498990202 / ACTION 0 / REWARD 0.1 / Q_MAX 5.086618e+00
# TIMESTEP 16062 / STATE explore / EPSILON 0.498990035367 / ACTION 0 / REWARD 0.1 / Q_MAX 5.176380e+00
# TIMESTEP 16063 / STATE explore / EPSILON 0.498989868733 / ACTION 0 / REWARD 0.1 / Q_MAX 5.066646e+00
# ----------Random Action----------
# TIMESTEP 16064 / STATE explore / EPSILON 0.4989897021 / ACTION 0 / REWARD 0.1 / Q_MAX 5.082773e+00
# TIMESTEP 16065 / STATE explore / EPSILON 0.498989535467 / ACTION 0 / REWARD 0.1 / Q_MAX 5.135143e+00
# TIMESTEP 16066 / STATE explore / EPSILON 0.498989368833 / ACTION 0 / REWARD 0.1 / Q_MAX 4.896760e+00
# TIMESTEP 16067 / STATE explore / EPSILON 0.4989892022 / ACTION 0 / REWARD 0.1 / Q_MAX 4.923904e+00
# TIMESTEP 16068 / STATE explore / EPSILON 0.498989035567 / ACTION 0 / REWARD 0.1 / Q_MAX 4.935040e+00
# ----------Random Action----------
# TIMESTEP 16069 / STATE explore / EPSILON 0.498988868933 / ACTION 1 / REWARD 0.1 / Q_MAX 5.099385e+00
# ----------Random Action----------
# TIMESTEP 16070 / STATE explore / EPSILON 0.4989887023 / ACTION 0 / REWARD 0.1 / Q_MAX 3.977849e+00
# ----------Random Action----------
# TIMESTEP 16071 / STATE explore / EPSILON 0.498988535667 / ACTION 0 / REWARD 0.1 / Q_MAX 4.699056e+00
# TIMESTEP 16072 / STATE explore / EPSILON 0.498988369033 / ACTION 1 / REWARD 0.1 / Q_MAX 4.051436e+00
# ----------Random Action----------
# TIMESTEP 16073 / STATE explore / EPSILON 0.4989882024 / ACTION 1 / REWARD 0.1 / Q_MAX 4.204232e+00
# ----------Random Action----------
# TIMESTEP 16074 / STATE explore / EPSILON 0.498988035767 / ACTION 0 / REWARD 0.1 / Q_MAX 4.051524e+00
# TIMESTEP 16075 / STATE explore / EPSILON 0.498987869133 / ACTION 0 / REWARD 0.1 / Q_MAX 4.276137e+00
# TIMESTEP 16076 / STATE explore / EPSILON 0.4989877025 / ACTION 0 / REWARD 0.1 / Q_MAX 3.811026e+00
# TIMESTEP 16077 / STATE explore / EPSILON 0.498987535867 / ACTION 0 / REWARD 0.1 / Q_MAX 3.530590e+00
# TIMESTEP 16078 / STATE explore / EPSILON 0.498987369233 / ACTION 0 / REWARD 0.1 / Q_MAX 2.435193e+00
# TIMESTEP 16079 / STATE explore / EPSILON 0.4989872026 / ACTION 0 / REWARD -1 / Q_MAX 2.177401e+00
# TIMESTEP 16080 / STATE explore / EPSILON 0.498987035967 / ACTION 0 / REWARD 0.1 / Q_MAX 7.394691e+00
# TIMESTEP 16081 / STATE explore / EPSILON 0.498986869333 / ACTION 0 / REWARD 0.1 / Q_MAX 7.362473e+00
# TIMESTEP 16082 / STATE explore / EPSILON 0.4989867027 / ACTION 0 / REWARD 0.1 / Q_MAX 7.092809e+00
# ----------Random Action----------
# TIMESTEP 16083 / STATE explore / EPSILON 0.498986536067 / ACTION 0 / REWARD 0.1 / Q_MAX 7.140375e+00
# ----------Random Action----------
# TIMESTEP 16084 / STATE explore / EPSILON 0.498986369433 / ACTION 0 / REWARD 0.1 / Q_MAX 7.099864e+00
# ----------Random Action----------
# TIMESTEP 16085 / STATE explore / EPSILON 0.4989862028 / ACTION 0 / REWARD 0.1 / Q_MAX 7.001311e+00
# ----------Random Action----------
# TIMESTEP 16086 / STATE explore / EPSILON 0.498986036167 / ACTION 1 / REWARD 0.1 / Q_MAX 7.085599e+00
# ----------Random Action----------
# TIMESTEP 16087 / STATE explore / EPSILON 0.498985869533 / ACTION 0 / REWARD 0.1 / Q_MAX 6.654133e+00
# ----------Random Action----------
# TIMESTEP 16088 / STATE explore / EPSILON 0.4989857029 / ACTION 0 / REWARD 0.1 / Q_MAX 6.512577e+00
# TIMESTEP 16089 / STATE explore / EPSILON 0.498985536267 / ACTION 1 / REWARD 0.1 / Q_MAX 6.474576e+00
# ----------Random Action----------
# TIMESTEP 16090 / STATE explore / EPSILON 0.498985369633 / ACTION 0 / REWARD 0.1 / Q_MAX 6.405223e+00
# TIMESTEP 16091 / STATE explore / EPSILON 0.498985203 / ACTION 0 / REWARD 0.1 / Q_MAX 6.357543e+00
# ----------Random Action----------
# TIMESTEP 16092 / STATE explore / EPSILON 0.498985036367 / ACTION 0 / REWARD 0.1 / Q_MAX 6.357756e+00
# TIMESTEP 16093 / STATE explore / EPSILON 0.498984869733 / ACTION 0 / REWARD 0.1 / Q_MAX 6.316373e+00
# ----------Random Action----------
# TIMESTEP 16094 / STATE explore / EPSILON 0.4989847031 / ACTION 0 / REWARD 0.1 / Q_MAX 6.407026e+00
# TIMESTEP 16095 / STATE explore / EPSILON 0.498984536467 / ACTION 0 / REWARD 0.1 / Q_MAX 6.478938e+00
# ----------Random Action----------
# TIMESTEP 16096 / STATE explore / EPSILON 0.498984369833 / ACTION 0 / REWARD 0.1 / Q_MAX 6.541659e+00
# ----------Random Action----------
# TIMESTEP 16097 / STATE explore / EPSILON 0.4989842032 / ACTION 1 / REWARD 0.1 / Q_MAX 6.554296e+00
# ----------Random Action----------
# TIMESTEP 16098 / STATE explore / EPSILON 0.498984036567 / ACTION 0 / REWARD 0.1 / Q_MAX 6.412513e+00
# TIMESTEP 16099 / STATE explore / EPSILON 0.498983869933 / ACTION 0 / REWARD 0.1 / Q_MAX 6.501099e+00
# TIMESTEP 16100 / STATE explore / EPSILON 0.4989837033 / ACTION 0 / REWARD 0.1 / Q_MAX 6.520303e+00
# TIMESTEP 16101 / STATE explore / EPSILON 0.498983536667 / ACTION 0 / REWARD 0.1 / Q_MAX 6.250169e+00
# TIMESTEP 16102 / STATE explore / EPSILON 0.498983370033 / ACTION 0 / REWARD 0.1 / Q_MAX 5.944415e+00
# TIMESTEP 16103 / STATE explore / EPSILON 0.4989832034 / ACTION 0 / REWARD 0.1 / Q_MAX 5.903726e+00
# ----------Random Action----------
# TIMESTEP 16104 / STATE explore / EPSILON 0.498983036767 / ACTION 0 / REWARD 0.1 / Q_MAX 5.798798e+00
# TIMESTEP 16105 / STATE explore / EPSILON 0.498982870133 / ACTION 0 / REWARD 0.1 / Q_MAX 5.774828e+00
# ----------Random Action----------
# TIMESTEP 16106 / STATE explore / EPSILON 0.4989827035 / ACTION 0 / REWARD 0.1 / Q_MAX 5.820535e+00
# ----------Random Action----------
# TIMESTEP 16107 / STATE explore / EPSILON 0.498982536867 / ACTION 0 / REWARD 0.1 / Q_MAX 5.588339e+00
# ----------Random Action----------
# TIMESTEP 16108 / STATE explore / EPSILON 0.498982370233 / ACTION 0 / REWARD 0.1 / Q_MAX 5.661866e+00
# ----------Random Action----------
# TIMESTEP 16109 / STATE explore / EPSILON 0.4989822036 / ACTION 0 / REWARD 0.1 / Q_MAX 5.661891e+00
# ----------Random Action----------
# TIMESTEP 16110 / STATE explore / EPSILON 0.498982036967 / ACTION 0 / REWARD 0.1 / Q_MAX 5.634454e+00
# ----------Random Action----------
# TIMESTEP 16111 / STATE explore / EPSILON 0.498981870333 / ACTION 0 / REWARD 0.1 / Q_MAX 5.580379e+00
# ----------Random Action----------
# TIMESTEP 16112 / STATE explore / EPSILON 0.4989817037 / ACTION 1 / REWARD 0.1 / Q_MAX 5.582817e+00
# ----------Random Action----------
# TIMESTEP 16113 / STATE explore / EPSILON 0.498981537067 / ACTION 0 / REWARD 0.1 / Q_MAX 5.228228e+00
# TIMESTEP 16114 / STATE explore / EPSILON 0.498981370433 / ACTION 0 / REWARD 0.1 / Q_MAX 4.469192e+00
# ----------Random Action----------
# TIMESTEP 16115 / STATE explore / EPSILON 0.4989812038 / ACTION 0 / REWARD 0.1 / Q_MAX 4.624927e+00
# ----------Random Action----------
# TIMESTEP 16116 / STATE explore / EPSILON 0.498981037167 / ACTION 0 / REWARD 0.1 / Q_MAX 4.466970e+00
# TIMESTEP 16117 / STATE explore / EPSILON 0.498980870533 / ACTION 0 / REWARD 0.1 / Q_MAX 4.646130e+00
# TIMESTEP 16118 / STATE explore / EPSILON 0.4989807039 / ACTION 0 / REWARD 0.1 / Q_MAX 4.561761e+00
# TIMESTEP 16119 / STATE explore / EPSILON 0.498980537267 / ACTION 0 / REWARD 0.1 / Q_MAX 4.590519e+00
# TIMESTEP 16120 / STATE explore / EPSILON 0.498980370633 / ACTION 0 / REWARD 0.1 / Q_MAX 4.874269e+00
# TIMESTEP 16121 / STATE explore / EPSILON 0.498980204 / ACTION 0 / REWARD 0.1 / Q_MAX 4.892140e+00
# ----------Random Action----------
# TIMESTEP 16122 / STATE explore / EPSILON 0.498980037367 / ACTION 0 / REWARD 0.1 / Q_MAX 4.900556e+00
# TIMESTEP 16123 / STATE explore / EPSILON 0.498979870733 / ACTION 0 / REWARD 0.1 / Q_MAX 4.761232e+00
# ----------Random Action----------
# TIMESTEP 16124 / STATE explore / EPSILON 0.4989797041 / ACTION 0 / REWARD 0.1 / Q_MAX 4.685619e+00
# TIMESTEP 16125 / STATE explore / EPSILON 0.498979537467 / ACTION 0 / REWARD 0.1 / Q_MAX 4.498698e+00
# ----------Random Action----------
# TIMESTEP 16126 / STATE explore / EPSILON 0.498979370833 / ACTION 0 / REWARD 0.1 / Q_MAX 4.460619e+00
# TIMESTEP 16127 / STATE explore / EPSILON 0.4989792042 / ACTION 0 / REWARD 0.1 / Q_MAX 4.464712e+00
# TIMESTEP 16128 / STATE explore / EPSILON 0.498979037567 / ACTION 0 / REWARD 0.1 / Q_MAX 4.388371e+00
# ----------Random Action----------
# TIMESTEP 16129 / STATE explore / EPSILON 0.498978870933 / ACTION 0 / REWARD 0.1 / Q_MAX 4.324195e+00
# TIMESTEP 16130 / STATE explore / EPSILON 0.4989787043 / ACTION 0 / REWARD 0.1 / Q_MAX 4.363062e+00
# TIMESTEP 16131 / STATE explore / EPSILON 0.498978537667 / ACTION 0 / REWARD 0.1 / Q_MAX 4.394293e+00
# ----------Random Action----------
# TIMESTEP 16132 / STATE explore / EPSILON 0.498978371033 / ACTION 1 / REWARD 0.1 / Q_MAX 3.885651e+00
# TIMESTEP 16133 / STATE explore / EPSILON 0.4989782044 / ACTION 0 / REWARD 0.1 / Q_MAX 4.284437e+00
# ----------Random Action----------
# TIMESTEP 16134 / STATE explore / EPSILON 0.498978037767 / ACTION 0 / REWARD 0.1 / Q_MAX 4.631797e+00
# TIMESTEP 16135 / STATE explore / EPSILON 0.498977871133 / ACTION 0 / REWARD 0.1 / Q_MAX 4.728973e+00
# ----------Random Action----------
# TIMESTEP 16136 / STATE explore / EPSILON 0.4989777045 / ACTION 0 / REWARD 0.1 / Q_MAX 4.844274e+00
# TIMESTEP 16137 / STATE explore / EPSILON 0.498977537867 / ACTION 0 / REWARD 0.1 / Q_MAX 4.589787e+00
# ----------Random Action----------
# TIMESTEP 16138 / STATE explore / EPSILON 0.498977371233 / ACTION 0 / REWARD 0.1 / Q_MAX 4.597276e+00
# TIMESTEP 16139 / STATE explore / EPSILON 0.4989772046 / ACTION 0 / REWARD 0.1 / Q_MAX 4.860994e+00
# TIMESTEP 16140 / STATE explore / EPSILON 0.498977037967 / ACTION 0 / REWARD 1 / Q_MAX 5.007751e+00
# TIMESTEP 16141 / STATE explore / EPSILON 0.498976871333 / ACTION 0 / REWARD 0.1 / Q_MAX 4.468273e+00
# ----------Random Action----------
# TIMESTEP 16142 / STATE explore / EPSILON 0.4989767047 / ACTION 0 / REWARD 0.1 / Q_MAX 4.408780e+00
# TIMESTEP 16143 / STATE explore / EPSILON 0.498976538067 / ACTION 0 / REWARD 0.1 / Q_MAX 4.392416e+00
# ----------Random Action----------
# TIMESTEP 16144 / STATE explore / EPSILON 0.498976371433 / ACTION 0 / REWARD 0.1 / Q_MAX 4.340933e+00
# ----------Random Action----------
# TIMESTEP 16145 / STATE explore / EPSILON 0.4989762048 / ACTION 0 / REWARD 0.1 / Q_MAX 4.298176e+00
# ----------Random Action----------
# TIMESTEP 16146 / STATE explore / EPSILON 0.498976038167 / ACTION 0 / REWARD 0.1 / Q_MAX 4.346534e+00
# TIMESTEP 16147 / STATE explore / EPSILON 0.498975871533 / ACTION 0 / REWARD 0.1 / Q_MAX 4.256171e+00
# ----------Random Action----------
# TIMESTEP 16148 / STATE explore / EPSILON 0.4989757049 / ACTION 0 / REWARD 0.1 / Q_MAX 4.446229e+00
# TIMESTEP 16149 / STATE explore / EPSILON 0.498975538267 / ACTION 0 / REWARD 0.1 / Q_MAX 4.361790e+00
# TIMESTEP 16150 / STATE explore / EPSILON 0.498975371633 / ACTION 0 / REWARD 0.1 / Q_MAX 4.415148e+00
# TIMESTEP 16151 / STATE explore / EPSILON 0.498975205 / ACTION 0 / REWARD 0.1 / Q_MAX 4.385284e+00
# ----------Random Action----------
# TIMESTEP 16152 / STATE explore / EPSILON 0.498975038367 / ACTION 0 / REWARD 0.1 / Q_MAX 4.269602e+00
# ----------Random Action----------
# TIMESTEP 16153 / STATE explore / EPSILON 0.498974871733 / ACTION 0 / REWARD 0.1 / Q_MAX 4.708658e+00
# ----------Random Action----------
# TIMESTEP 16154 / STATE explore / EPSILON 0.4989747051 / ACTION 0 / REWARD 0.1 / Q_MAX 4.691458e+00
# TIMESTEP 16155 / STATE explore / EPSILON 0.498974538467 / ACTION 0 / REWARD 0.1 / Q_MAX 4.847213e+00
# TIMESTEP 16156 / STATE explore / EPSILON 0.498974371833 / ACTION 0 / REWARD 0.1 / Q_MAX 4.945104e+00
# TIMESTEP 16157 / STATE explore / EPSILON 0.4989742052 / ACTION 1 / REWARD 0.1 / Q_MAX 5.006106e+00
# TIMESTEP 16158 / STATE explore / EPSILON 0.498974038567 / ACTION 1 / REWARD 0.1 / Q_MAX 4.747188e+00
# ----------Random Action----------
# TIMESTEP 16159 / STATE explore / EPSILON 0.498973871933 / ACTION 0 / REWARD 0.1 / Q_MAX 4.617044e+00
# ----------Random Action----------
# TIMESTEP 16160 / STATE explore / EPSILON 0.4989737053 / ACTION 0 / REWARD 0.1 / Q_MAX 4.468649e+00
# TIMESTEP 16161 / STATE explore / EPSILON 0.498973538667 / ACTION 0 / REWARD 0.1 / Q_MAX 4.127354e+00
# TIMESTEP 16162 / STATE explore / EPSILON 0.498973372033 / ACTION 0 / REWARD 0.1 / Q_MAX 4.121287e+00
# TIMESTEP 16163 / STATE explore / EPSILON 0.4989732054 / ACTION 0 / REWARD 0.1 / Q_MAX 4.137201e+00
# ----------Random Action----------
# TIMESTEP 16164 / STATE explore / EPSILON 0.498973038767 / ACTION 0 / REWARD 0.1 / Q_MAX 4.131419e+00
# TIMESTEP 16165 / STATE explore / EPSILON 0.498972872133 / ACTION 0 / REWARD 0.1 / Q_MAX 4.185327e+00
# ----------Random Action----------
# TIMESTEP 16166 / STATE explore / EPSILON 0.4989727055 / ACTION 0 / REWARD 0.1 / Q_MAX 4.271076e+00
# ----------Random Action----------
# TIMESTEP 16167 / STATE explore / EPSILON 0.498972538867 / ACTION 0 / REWARD 0.1 / Q_MAX 4.476563e+00
# ----------Random Action----------
# TIMESTEP 16168 / STATE explore / EPSILON 0.498972372233 / ACTION 1 / REWARD 0.1 / Q_MAX 4.625808e+00
# TIMESTEP 16169 / STATE explore / EPSILON 0.4989722056 / ACTION 0 / REWARD 0.1 / Q_MAX 3.473958e+00
# TIMESTEP 16170 / STATE explore / EPSILON 0.498972038967 / ACTION 0 / REWARD 0.1 / Q_MAX 1.666784e+00
# TIMESTEP 16171 / STATE explore / EPSILON 0.498971872333 / ACTION 0 / REWARD 0.1 / Q_MAX -5.416000e-01
# ----------Random Action----------
# TIMESTEP 16172 / STATE explore / EPSILON 0.4989717057 / ACTION 0 / REWARD -1 / Q_MAX -1.968371e+00
# TIMESTEP 16173 / STATE explore / EPSILON 0.498971539067 / ACTION 0 / REWARD 0.1 / Q_MAX 7.083547e+00
# ----------Random Action----------
# TIMESTEP 16174 / STATE explore / EPSILON 0.498971372433 / ACTION 0 / REWARD 0.1 / Q_MAX 7.130536e+00
# TIMESTEP 16175 / STATE explore / EPSILON 0.4989712058 / ACTION 0 / REWARD 0.1 / Q_MAX 6.943458e+00
# ----------Random Action----------
# TIMESTEP 16176 / STATE explore / EPSILON 0.498971039167 / ACTION 0 / REWARD 0.1 / Q_MAX 7.150958e+00
# ----------Random Action----------
# TIMESTEP 16177 / STATE explore / EPSILON 0.498970872533 / ACTION 0 / REWARD 0.1 / Q_MAX 7.161875e+00
# ----------Random Action----------
# TIMESTEP 16178 / STATE explore / EPSILON 0.4989707059 / ACTION 0 / REWARD 0.1 / Q_MAX 7.130239e+00
# ----------Random Action----------
# TIMESTEP 16179 / STATE explore / EPSILON 0.498970539267 / ACTION 0 / REWARD 0.1 / Q_MAX 7.188725e+00
# ----------Random Action----------
# TIMESTEP 16180 / STATE explore / EPSILON 0.498970372633 / ACTION 0 / REWARD 0.1 / Q_MAX 7.118165e+00
# ----------Random Action----------
# TIMESTEP 16181 / STATE explore / EPSILON 0.498970206 / ACTION 0 / REWARD 0.1 / Q_MAX 7.272612e+00
# ----------Random Action----------
# TIMESTEP 16182 / STATE explore / EPSILON 0.498970039367 / ACTION 0 / REWARD 0.1 / Q_MAX 7.253979e+00
# ----------Random Action----------
# TIMESTEP 16183 / STATE explore / EPSILON 0.498969872733 / ACTION 0 / REWARD 0.1 / Q_MAX 7.207619e+00
# TIMESTEP 16184 / STATE explore / EPSILON 0.4989697061 / ACTION 1 / REWARD 0.1 / Q_MAX 7.180873e+00
# ----------Random Action----------
# TIMESTEP 16185 / STATE explore / EPSILON 0.498969539467 / ACTION 0 / REWARD 0.1 / Q_MAX 7.173532e+00
# TIMESTEP 16186 / STATE explore / EPSILON 0.498969372833 / ACTION 0 / REWARD 0.1 / Q_MAX 7.191264e+00
# ----------Random Action----------
# TIMESTEP 16187 / STATE explore / EPSILON 0.4989692062 / ACTION 0 / REWARD 0.1 / Q_MAX 7.315733e+00
# ----------Random Action----------
# TIMESTEP 16188 / STATE explore / EPSILON 0.498969039567 / ACTION 0 / REWARD 0.1 / Q_MAX 7.282513e+00
# TIMESTEP 16189 / STATE explore / EPSILON 0.498968872933 / ACTION 0 / REWARD 0.1 / Q_MAX 7.209599e+00
# ----------Random Action----------
# TIMESTEP 16190 / STATE explore / EPSILON 0.4989687063 / ACTION 0 / REWARD 0.1 / Q_MAX 7.174372e+00
# TIMESTEP 16191 / STATE explore / EPSILON 0.498968539667 / ACTION 0 / REWARD 0.1 / Q_MAX 7.234010e+00
# TIMESTEP 16192 / STATE explore / EPSILON 0.498968373033 / ACTION 0 / REWARD 0.1 / Q_MAX 7.152832e+00
